# %% [markdown]
# ## IOWA STATE UNIVERSITY ENROLLMENT DATA
#
# About this Data
# Contains data from fall 1998 through spring 2022 regarding enrollment statistics from Iowa State University. Is broken down between year, semester, and student classification. Post-Doc data only available from Fall 2011 through Summer 2018.

# %%
#importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("ISU Enrollment.csv")
df
# Out:
#     Year Semester  Ungrad  Prof  Grad  Post-Doc  Total
# 0   2022   Spring   24482   632  4122         0  29236
# 1   2021     Fall   25808   636  4264         0  30708
# 2   2021   Summer    6202   159  2713         0   9074
# 3   2021   Spring   24482   621  4265         0  29368
# 4   2020     Fall   26846   627  4352         0  31825
# ..   ...      ...     ...   ...   ...       ...    ...
# 66  2000   Spring   20251     0  4082         0  24333
# 67  1999     Fall   21901     0  4209         0  26110
# 68  1999   Summer    6033     0  2858         0   8891
# 69  1999   Spring   19825     0  4048         0  23873
# 70  1998     Fall   21427     0  4158         0  25585
#
# [71 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      71 non-null     int64
#  1   Semester  71 non-null     object
#  2   Ungrad    71 non-null     int64
#  3   Prof      71 non-null     int64
#  4   Grad      71 non-null     int64
#  5   Post-Doc  71 non-null     int64
#  6   Total     71 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 4.0+ KB

# %%
df.describe().T
# Out:
#           count          mean          std     min      25%      50%      75%  \
# Year       71.0   2010.000000     6.890988  1998.0   2004.0   2010.0   2016.0
# Ungrad     71.0  18322.591549  8466.391096  5712.0   7725.5  21033.0  24482.0
# Prof       71.0    337.323944   242.918492     0.0    121.5    408.0    586.0
# Grad       71.0   4081.478873   741.795868  2713.0   3170.0   4364.0   4651.0
# Post-Doc   71.0     91.084507   141.837809     0.0      0.0      0.0    289.5
# Total      71.0  22832.478873  9375.979161  8891.0  11381.5  25863.0  29650.5
#
#               max
# Year       2022.0
# Ungrad    30671.0
# Prof        636.0
# Grad       5096.0
# Post-Doc    345.0
# Total     36660.0

# %%
df.isnull().sum()
# Out:
# Year        0
# Semester    0
# Ungrad      0
# Prof        0
# Grad        0
# Post-Doc    0
# Total       0
# dtype: int64

# %%
df.shape
# Out:
# (71, 7)

# %% [markdown]
# we can split the semester column based on semester name using get dummies but also we can use lambda function to do this

# %%
df.Semester.value_counts()
# Out:
# Spring    24
# Fall      24
# Summer    23
# Name: Semester, dtype: int64

# %%
df.head()
# Out:
#    Year Semester  Ungrad  Prof  Grad  Post-Doc  Total
# 0  2022   Spring   24482   632  4122         0  29236
# 1  2021     Fall   25808   636  4264         0  30708
# 2  2021   Summer    6202   159  2713         0   9074
# 3  2021   Spring   24482   621  4265         0  29368
# 4  2020     Fall   26846   627  4352         0  31825

# %%
df.head()
# Out:
#    Year Semester  Ungrad  Prof  Grad  Post-Doc  Total
# 0  2022   Spring   24482   632  4122         0  29236
# 1  2021     Fall   25808   636  4264         0  30708
# 2  2021   Summer    6202   159  2713         0   9074
# 3  2021   Spring   24482   621  4265         0  29368
# 4  2020     Fall   26846   627  4352         0  31825

# %%
df['Post_Doc']=df['Post-Doc']
df.drop(columns=['Post-Doc'],inplace=True)

# %%
sns.countplot(x=df['Semester'])
# Out:
# <AxesSubplot:xlabel='Semester', ylabel='count'>

# %%
#seperating Semester Column Based on Category
Fall = df.loc[(df.Semester == "Fall")]
Spring = df.loc[(df.Semester == "Spring")]
Summer = df.loc[(df.Semester == "Summer")]

# %%
Fall.head()
# Out:
#     Year Semester  Ungrad  Prof  Grad  Total  Post_Doc
# 1   2021     Fall   25808   636  4264  30708         0
# 4   2020     Fall   26846   627  4352  31825         0
# 7   2019     Fall   28294   599  4498  33391         0
# 10  2018     Fall   29621   597  4774  34992         0
# 13  2017     Fall   30406   596  4991  36321       328

# %%
plt.rcParams['figure.figsize'] = (15, 5)

plt.subplot(131)
sns.lineplot(x=Fall.Year,y = Fall.Ungrad)
plt.title('Fall semester Ungrad Enrollment', fontsize = 20)
plt.xlabel('Year')
plt.ylabel('Ungrad')
plt.axvline(x=2020, color='red', linestyle='--')

plt.subplot(132)
sns.lineplot(x=Fall.Year,y = Fall.Prof)
plt.title('Fall Semester Prof Enrollment', fontsize = 20)
plt.xlabel('Year')
plt.ylabel('Prof')
plt.axvline(x=2020, color='red', linestyle='--')

plt.subplot(133)
sns.lineplot(x=Fall.Year,y = Fall.Grad)
plt.title('Fall semester  Grad Enrollment', fontsize = 20)
plt.xlabel('Year')
plt.ylabel('Grad')
plt.axvline(x=2020, color='red', linestyle='--')

plt.show()

# %%
plt.subplot(131)
sns.lineplot(x=Fall.Year,y = Fall.Post_Doc)
plt.title('Fall semester Post_Doc Enrollment', fontsize = 20)
plt.xlabel('Year')
plt.ylabel('Post_Doc')
plt.axvline(x=2020, color='red', linestyle='--')

plt.subplot(132)
sns.lineplot(x=Spring.Year,y = Spring.Post_Doc)
plt.title('Spring Post_Doc Enrollment', fontsize = 20)
plt.xlabel('Year')
plt.ylabel('Post_Doc')
plt.axvline(x=2020, color='red', linestyle='--')


plt.subplot(133)
sns.lineplot(x=Summer.Year,y = Summer.Post_Doc)
plt.title('Summer Post_Doc Enrollment', fontsize = 20)
plt.xlabel('Year')
plt.ylabel('Post_Doc')
plt.axvline(x=2020, color='red', linestyle='--')

# %%
plt.rcParams['figure.figsize'] = (15,5)

plt.subplot(131)
sns.lineplot(x=Spring.Year,y = Spring.Ungrad)
plt.title('Spring  Ungrad Enrollment', fontsize = 20)
plt.xlabel('Year')
plt.ylabel('Ungrad')
plt.axvline(x=2020, color='red', linestyle='--')


plt.subplot(132)
sns.lineplot(x=Spring.Year,y = Spring.Prof)
plt.title('Spring Prof Enrollment', fontsize = 20)
plt.xlabel('Year')
plt.ylabel('Prof')
plt.axvline(x=2020, color='red', linestyle='--')


plt.subplot(133)
sns.lineplot(x=Spring.Year,y = Spring.Grad)
plt.title('Spring Grad Enrollment', fontsize = 20)
plt.xlabel('Year')
plt.ylabel('Grad')
plt.axvline(x=2020, color='red', linestyle='--')



plt.show()

# %%
plt.rcParams['figure.figsize'] = (15,5)

plt.subplot(131)
sns.lineplot(x=Summer.Year,y = Summer.Ungrad)
plt.title('Summer  Ungrad Enrollment', fontsize = 20)
plt.xlabel('Year')
plt.ylabel('Ungrad')
plt.axvline(x=2020, color='red', linestyle='--')


plt.subplot(132)
sns.lineplot(x=Summer.Year,y = Summer.Prof)
plt.title('Summer Prof Enrollment', fontsize = 20)
plt.xlabel('Year')
plt.ylabel('Prof')
plt.axvline(x=2020, color='red', linestyle='--')


plt.subplot(133)
sns.lineplot(x=Summer.Year,y = Summer.Grad)
plt.title('Summer Grad Enrollment', fontsize = 20)
plt.xlabel('Year')
plt.ylabel('Grad')
plt.axvline(x=2020, color='red', linestyle='--')



plt.show()

# %% [markdown]
# # Above  Red lines are  for Marking COVID-19

# %%
plt.rcParams["figure.figsize"] = (15,10)
plt.plot('Year','Total',data=Fall, color = "tab:red")
plt.plot('Year', 'Total', data=Spring, color ="tab:green")
plt.plot('Year', 'Total', data=Summer, color = "tab:blue")
plt.legend(['Total Enrollment - Fall', 'Total Enrollment - Spring', 
            'Total Enrollment - Summer'],fontsize="large")
plt.axvline(x=2020, color='black', linestyle='--')
plt.show()

# %%
df
# Out:
#     Year Semester  Ungrad  Prof  Grad  Total  Post_Doc
# 0   2022   Spring   24482   632  4122  29236         0
# 1   2021     Fall   25808   636  4264  30708         0
# 2   2021   Summer    6202   159  2713   9074         0
# 3   2021   Spring   24482   621  4265  29368         0
# 4   2020     Fall   26846   627  4352  31825         0
# ..   ...      ...     ...   ...   ...    ...       ...
# 66  2000   Spring   20251     0  4082  24333         0
# 67  1999     Fall   21901     0  4209  26110         0
# 68  1999   Summer    6033     0  2858   8891         0
# 69  1999   Spring   19825     0  4048  23873         0
# 70  1998     Fall   21427     0  4158  25585         0
#
# [71 rows x 7 columns]

# %%
#outlier Detection

# %%
columns = df.columns
columns
# Out:
# Index(['Year', 'Semester', 'Ungrad', 'Prof', 'Grad', 'Total', 'Post_Doc'], dtype='object')

# %%
#Boxplot of Ungrad
sns.boxplot(x=df['Ungrad'])
# Out:
# <AxesSubplot:xlabel='Ungrad'>

# %%
#prof outlier
sns.boxplot(x=df['Prof'])
# Out:
# <AxesSubplot:xlabel='Prof'>

# %%
#boxplot of Grad
sns.boxplot(x=df['Grad'])
# Out:
# <AxesSubplot:xlabel='Grad'>

# %%
#boxplot of  Post Doc
sns.boxplot(x=df['Post_Doc'])
# Out:
# <AxesSubplot:xlabel='Post_Doc'>

# %%
#mapping the Semester column
df['Spring'] = df['Semester'].apply(lambda x : 1 if "Spring" in x else 0)
df['Summer'] = df['Semester'].apply(lambda x : 1 if "Summer" in x else 0)
df['Fall'] = df['Semester'].apply(lambda x : 1 if "Fall" in x else 0)

# %%
df.head()
# Out:
#    Year Semester  Ungrad  Prof  Grad  Total  Post_Doc  Spring  Summer  Fall
# 0  2022   Spring   24482   632  4122  29236         0       1       0     0
# 1  2021     Fall   25808   636  4264  30708         0       0       0     1
# 2  2021   Summer    6202   159  2713   9074         0       0       1     0
# 3  2021   Spring   24482   621  4265  29368         0       1       0     0
# 4  2020     Fall   26846   627  4352  31825         0       0       0     1

# %%
df.drop(columns=['Semester'],inplace = True)

# %%
df.head()
# Out:
#    Year  Ungrad  Prof  Grad  Total  Post_Doc  Spring  Summer  Fall
# 0  2022   24482   632  4122  29236         0       1       0     0
# 1  2021   25808   636  4264  30708         0       0       0     1
# 2  2021    6202   159  2713   9074         0       0       1     0
# 3  2021   24482   621  4265  29368         0       1       0     0
# 4  2020   26846   627  4352  31825         0       0       0     1

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = 20,8
sns.heatmap(df.corr(),annot=True,cmap="jet")
# Out:
# <AxesSubplot:>

# %%
#Pairplot and Relation Between Target and Other Columns to find the Better Features
plt.figure(figsize=(14,8))
sns.pairplot(df,x_vars=['Year','Ungrad', 'Prof', 'Grad','Post_Doc','Spring','Summer','Fall'],y_vars='Total',height = 4,aspect = 0.5,kind='reg')

# %%
#Splitting X and Y for model creation
X=df.drop(columns=['Total'])
X
# Out:
#     Year  Ungrad  Prof  Grad  Post_Doc  Spring  Summer  Fall
# 0   2022   24482   632  4122         0       1       0     0
# 1   2021   25808   636  4264         0       0       0     1
# 2   2021    6202   159  2713         0       0       1     0
# 3   2021   24482   621  4265         0       1       0     0
# 4   2020   26846   627  4352         0       0       0     1
# ..   ...     ...   ...   ...       ...     ...     ...   ...
# 66  2000   20251     0  4082         0       1       0     0
# 67  1999   21901     0  4209         0       0       0     1
# 68  1999    6033     0  2858         0       0       1     0
# 69  1999   19825     0  4048         0       1       0     0
# 70  1998   21427     0  4158         0       0       0     1
#
# [71 rows x 8 columns]

# %%
Y = df['Total']
Y
# Out:
# 0     29236
# 1     30708
# 2      9074
# 3     29368
# 4     31825
#       ...
# 66    24333
# 67    26110
# 68     8891
# 69    23873
# 70    25585
# Name: Total, Length: 71, dtype: int64

# %%
#Train test split
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=0)

# %% [markdown]
# # Model Creation

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
LR = LinearRegression()
LR.fit(X_train,Y_train)
Y_pred=LR.predict(X_test)
print("r2score",r2_score(Y_test,Y_pred))
print("mean_squared_error",mean_squared_error(Y_test,Y_pred))
print("mean_absolute_error",mean_absolute_error(Y_test,Y_pred))
# Out:
# r2score 1.0
# mean_squared_error 2.2773201353154357e-21
# mean_absolute_error 4.112937151350909e-11

# %% [markdown]
# # KNN Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
mse = []
r2 = []
for i in range(1,10):
    KNR = KNeighborsRegressor(n_neighbors=i)
    KNR.fit(X_train,Y_train)
    y_pred = KNR.predict(X_test)
    mse_i = mean_squared_error(Y_test,Y_pred)
    mse.append(mse_i)
    r2_i = r2_score(Y_test,Y_pred)
    r2.append(r2_i)
#     print('i = {}, mse = {} , r2 = {}'.format(i,mse_i,r2_i))

# %%
#plotting K values 
plt.figure(figsize = (8,8))
plt.plot(np.arange(1,10),mse,'r')
plt.xlabel('k-value')
plt.ylabel('mean-squared-error')
plt.title('Selecting k-value')
plt.show()

# %%
KNR = KNeighborsRegressor(n_neighbors=5)
KNR.fit(X_train,Y_train)
Y_pred = KNR.predict(X_test)

# %%
print("r2score",r2_score(Y_test,Y_pred))
print("mean_squared_error",mean_squared_error(Y_test,Y_pred))
print("mean_absolute_error",mean_absolute_error(Y_test,Y_pred))
# Out:
# r2score 0.9927542857833508
# mean_squared_error 456088.75999999983
# mean_absolute_error 567.4888888888886
